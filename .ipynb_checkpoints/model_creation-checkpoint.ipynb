# %%
import pandas as pd
import numpy as np

# %%
columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "car_name",]

# %%
df = pd.read_csv('./data/auto-mpg.data', names=columns)
df[30:40]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 30  28.0          4         140.0      90.00   2264.          15.5
# 31  25.0          4         113.0      95.00   2228.          14.0
# 32  25.0          4          98.0          ?                2046.0
# 33  19.0          6         232.0      100.0   2634.          13.0
# 34  16.0          6         225.0      105.0   3439.          15.5
# 35  17.0          6         250.0      100.0   3329.          15.5
# 36  19.0          6         250.0      88.00   3302.          15.5
# 37  18.0          6         232.0      100.0   3288.          15.5
# 38  14.0          8         350.0      165.0   4209.          12.0
# 39  14.0          8         400.0      175.0   4464.          11.5
#
#     model_year  origin                      car_name
# 30        71.0       1         "chevrolet vega 2300"
# 31        71.0       3               "toyota corona"
# 32        19.0      71                             1
# 33        71.0       1                 "amc gremlin"
# 34        71.0       1   "plymouth satellite custom"
# 35        71.0       1   "chevrolet chevelle malibu"
# 36        71.0       1             "ford torino 500"
# 37        71.0       1                 "amc matador"
# 38        71.0       1            "chevrolet impala"
# 39        71.0       1   "pontiac catalina brougham"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      398 non-null object
# weight          398 non-null object
# acceleration    398 non-null float64
# model_year      398 non-null float64
# origin          398 non-null int64
# car_name        398 non-null object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 28.1+ KB

# %%
def clean_data(df):
    # create list of columns to convert to numeric
    columns_to_convert = ['horsepower', 'weight']
    clean_df = df
    # iterate over the columns in our custom list
    for column in columns_to_convert:
        # set dataframe to itself, with the converted values
        clean_df = clean_df[pd.to_numeric(clean_df[column], errors='coerce').notnull()] # non-numeric will be set to NaN, then removed
    return(clean_df)

# %%
df.shape
# Out:
# (398, 9)

# %%
clean_df = clean_data(df)

# %%
clean_df.shape
# Out:
# (392, 9)

# %%
clean_df[30:40]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 30  28.0          4         140.0      90.00   2264.          15.5
# 31  25.0          4         113.0      95.00   2228.          14.0
# 33  19.0          6         232.0      100.0   2634.          13.0
# 34  16.0          6         225.0      105.0   3439.          15.5
# 35  17.0          6         250.0      100.0   3329.          15.5
# 36  19.0          6         250.0      88.00   3302.          15.5
# 37  18.0          6         232.0      100.0   3288.          15.5
# 38  14.0          8         350.0      165.0   4209.          12.0
# 39  14.0          8         400.0      175.0   4464.          11.5
# 40  14.0          8         351.0      153.0   4154.          13.5
#
#     model_year  origin                      car_name
# 30        71.0       1         "chevrolet vega 2300"
# 31        71.0       3               "toyota corona"
# 33        71.0       1                 "amc gremlin"
# 34        71.0       1   "plymouth satellite custom"
# 35        71.0       1   "chevrolet chevelle malibu"
# 36        71.0       1             "ford torino 500"
# 37        71.0       1                 "amc matador"
# 38        71.0       1            "chevrolet impala"
# 39        71.0       1   "pontiac catalina brougham"
# 40        71.0       1            "ford galaxie 500"

# %%
print(clean_df['mpg'].nunique())
print(clean_df['mpg'].min())
print(clean_df['mpg'].max())
# Out:
# 127
# 9.0
# 46.6

# %%
bins = [0,15,23,30,35,50]
bin_names = ["0-15", "15-23", "23-30", "30-35", "35+"]
clean_df["mpg_class"] = pd.cut(clean_df["mpg"], bins=bins, labels=bin_names)

# %%
# verify bins
clean_df[["mpg","mpg_class"]].head(10)
# Out:
#     mpg mpg_class
# 0  18.0     15-23
# 1  15.0      0-15
# 2  18.0     15-23
# 3  16.0     15-23
# 4  17.0     15-23
# 5  15.0      0-15
# 6  14.0      0-15
# 7  14.0      0-15
# 8  14.0      0-15
# 9  15.0      0-15

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder().fit(clean_df["mpg_class"])

# %%
clean_df["target"] = le.transform(clean_df["mpg_class"])

# %%
clean_df.sample(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 308  33.5          4         151.0      90.00   2556.          13.2
# 31   25.0          4         113.0      95.00   2228.          14.0
# 8    14.0          8         455.0      225.0   4425.          10.0
# 176  19.0          6         232.0      90.00   3211.          17.0
# 27   11.0          8         318.0      210.0   4382.          13.5
# 311  32.1          4          98.0      70.00   2120.          15.5
# 2    18.0          8         318.0      150.0   3436.          11.0
# 190  14.5          8         351.0      152.0   4215.          12.8
# 249  19.9          8         260.0      110.0   3365.          15.5
# 20   25.0          4         110.0      87.00   2672.          17.5
#
#      model_year  origin                              car_name mpg_class  \
# 308        79.0       1                     "pontiac phoenix"     30-35
# 31         71.0       3                       "toyota corona"     23-30
# 8          70.0       1                    "pontiac catalina"      0-15
# 176        75.0       1                           "amc pacer"     15-23
# 27         70.0       1                          "dodge d200"      0-15
# 311        80.0       1                  "chevrolet chevette"     30-35
# 2          70.0       1                  "plymouth satellite"     15-23
# 190        76.0       1                    "ford gran torino"      0-15
# 249        78.0       1   "oldsmobile cutlass salon brougham"     15-23
# 20         70.0       2                         "peugeot 504"     23-30
#
#      target
# 308       3
# 31        2
# 8         0
# 176       1
# 27        0
# 311       3
# 2         1
# 190       0
# 249       1
# 20        2

# %%
clean_df.corr()
# Out:
#                    mpg  cylinders  displacement  acceleration  model_year  \
# mpg           1.000000  -0.777618     -0.805127      0.423329    0.580541
# cylinders    -0.777618   1.000000      0.950823     -0.504683   -0.345647
# displacement -0.805127   0.950823      1.000000     -0.543800   -0.369855
# acceleration  0.423329  -0.504683     -0.543800      1.000000    0.290316
# model_year    0.580541  -0.345647     -0.369855      0.290316    1.000000
# origin        0.565209  -0.568932     -0.614535      0.212746    0.181528
# target        0.965240  -0.738250     -0.772535      0.400492    0.594228
#
#                 origin    target
# mpg           0.565209  0.965240
# cylinders    -0.568932 -0.738250
# displacement -0.614535 -0.772535
# acceleration  0.212746  0.400492
# model_year    0.181528  0.594228
# origin        1.000000  0.561862
# target        0.561862  1.000000

# %%
X = clean_df.drop(columns=["mpg", "mpg_class", "target", "car_name"])
X.head()
# Out:
#    cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0          8         307.0      130.0   3504.          12.0        70.0
# 1          8         350.0      165.0   3693.          11.5        70.0
# 2          8         318.0      150.0   3436.          11.0        70.0
# 3          8         304.0      150.0   3433.          12.0        70.0
# 4          8         302.0      140.0   3449.          10.5        70.0
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
y = clean_df["target"]
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=200, random_state=0)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.7244897959183674

# %%
import pickle

# %%
filename="./model/mpg_model"
pickle.dump(clf, open(filename, 'wb'))

# %%
np.save('./model/classes.npy', le.classes_)
